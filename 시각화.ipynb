# %%
import time

# %%
print('잠자는 중...')
time.sleep(10)
print('일어났다')
# Out:
# 잠자는 중...
# 일어났다

# %%
text = '나는 파이썬 전문가일까,,'
text2 = r'$text\n'
text2
# Out:
# '$text\\n'

# %%
# %%html
# <font color='red'>안녕? 난 HTML이야</font>
# Out:
# <font color='red'>안녕? 난 HTML이야</font>

# %%
# %%html
# <marquee style='width:30%;color="blue"'><b>파이팅</b></marquee>
# Out:
# <marquee style='width:30%;color="blue"'><b>파이팅</b></marquee>

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
y = 200+np.random.randn(100)

# %%
x = [x for x in range(len(y))]

# %%
plt.plot(x,y,'-')
plt.title('Filled Example')
plt.fill_between(x, y, 195, where=(y > 195), facecolor='g', alpha=0.3)
plt.show()
